# %%
import matplotlib.pyplot as pl
import pandas as pd

# %%
dataset=pd.read_csv("tourists_nepal.csv")

# %%
# dataset.head()
x=dataset['2016']
y=dataset['Top Five Country of Nationality:']

# %%
pl.xlabel('Year')
pl.ylabel('Country')


pl.bar(x,y)
# Out:
# <BarContainer object of 5 artists>
